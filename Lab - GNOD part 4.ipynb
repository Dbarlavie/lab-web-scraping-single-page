# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd
import re
from datetime import datetime

# %%
url = "https://www.popvortex.com/music/charts/top-100-songs.php"

# %%
response = requests.get(url)

# %%
response.status_code
# Out:
# 200

# %%
soup = BeautifulSoup(response.content, "html.parser")
# soup

# %%
song_elements=soup.find_all('div', class_='chart-content')

# %%
if not song_elements:
    print("No song elements found. Please check if the website structure has changed.")
    exit()

data = []
for i, element in enumerate(song_elements):
    title = element.find('cite', class_='title').text.strip()
    artist = element.find('em', class_='artist').text.strip()

    # Extracting genre
    genre = "Genre not found"
    ul_tag = element.find('ul')
    if ul_tag:
        for li_tag in ul_tag.find_all('li'):
            if 'Genre' in li_tag.text:
                genre = li_tag.text.strip().replace('Genre:', '')
                break

   # Extracting release date using regular expression
    release_date_text = ""
    release_date_match = re.search(r'Release Date: (\w+ \d{1,2}, \d{4})', element.get_text())
    if release_date_match:
        release_date_text = release_date_match.group(1)
        
        # Convert release date to date format
        release_date = datetime.strptime(release_date_text, "%B %d, %Y").strftime("%d/%m/%Y")

    data.append([title, artist, genre, release_date])

df = pd.DataFrame(data, columns=['title', 'artist', 'genre', 'release_date'])
df.head()
# Out:
#               title        artist           genre release_date
# 0    TEXAS HOLD 'EM       Beyoncé         Country   11/02/2024
# 1      Lose Control   Teddy Swims             Pop   23/06/2023
# 2  Beautiful Things  Benson Boone             Pop   19/01/2024
# 3    TEXAS HOLD 'EM       Beyoncé         Country   09/02/2024
# 4    dont let me go           mgk   Hip-Hop / Rap   21/02/2024

# %%
# first ask for a songfrom user
# if title in df then dive new song from df
# if title not in df answer politely

# %%
def recommend_song(df, input_song):
    # Convert input to lowercase for case-insensitive comparison
    input_song = input_song.lower()
    
    # Check if the input song is in the DataFrame
    if input_song in df['title'].str.lower().values:
        # Get a random song that is not the input song
        random_song = df[df['title'].str.lower() != input_song].sample(n=1)
        recommended_song = random_song.iloc[0]['title']
        recommended_artist = random_song.iloc[0]['artist']
        print(f"Thanks for answering {input_song}. Based on your input, we reccomend {recommended_song} by {recommended_artist}.")
    else:
        print("We have no recommendation at this time.")

# %%
user_input = input("Enter a song title: ")
recommend_song(df, user_input)
# Out:
# Enter a song title: flowers
# Thanks for answering flowers. Based on your input, we reccomend Country's Cool Again by Lainey Wilson.

# %% [markdown]
# # API wrappers

# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
from pandas import json_normalize

# %%
secrets_file = open("secrets.txt","r")

# %%
string = secrets_file.read()

# %%
string.split('\n')
# Out:
# ['client_id:0a3904a89c3240788c3df162f505438c',
#  'client_secret:087560078b984a6ba8972510db24aee9']

# %%
secrets_dict={}
for line in string.split('\n'):
    if len(line) > 0:
        #print(line.split(':'))
        secrets_dict[line.split(':')[0]]=line.split(':')[1].strip()

# %%
from spotipy.oauth2 import SpotifyClientCredentials

#Initialize SpotiPy with user credentials
sp = spotipy.Spotify(auth_manager=SpotifyClientCredentials(client_id=secrets_dict['client_id'],
                                                           client_secret=secrets_dict['client_secret']))

# %%
playlist = sp.user_playlist_tracks("spotify", "1TM3rECdFTc0R0tgiIf0oW")

# %%
playlist.keys()
# Out:
# dict_keys(['href', 'items', 'limit', 'next', 'offset', 'previous', 'total'])

# %% [markdown]
# ## Additional Playlist and Features

# %%
from random import randint
from time import sleep

def get_playlist_tracks(playlist_id):
    results = sp.user_playlist_tracks("spotify",playlist_id)
    tracks = results['items']
    while results['next']!=None:
        results = sp.next(results)
        tracks = tracks + results['items']
        sleep(randint(1,3000)/1000) # respectful nap
    return tracks

# %%
all_tracks = get_playlist_tracks("1TM3rECdFTc0R0tgiIf0oW")
len(all_tracks)
# Out:
# 4690

# %%
songs = json_normalize(all_tracks)

# %%
# songs

# %%
artists_df = pd.DataFrame(columns=['href', 'id', 'name', 'type', 'uri', 'external_urls.spotify','song_id', 'song_name', 'popularity' ])
for i in songs.index:
    artists_for_song = json_normalize(songs.iloc[i]['track.artists'])
    artists_for_song['song_id']    = songs.iloc[i]['track.id']         # we want to keep song_id, it is the same for all artists
    artists_for_song['song_name']  = songs.iloc[i]['track.name']       # we want to keep song_name, it is the sae for all artists
    artists_for_song['popularity'] = songs.iloc[i]['track.popularity'] # same for popularity   
    artists_df = pd.concat([artists_df, artists_for_song], axis=0)

# %%
df_final = artists_df[['song_name', 'name', 'song_id', 'popularity']].dropna()
df_final
# Out:
#                                       song_name               name  \
# 0                                 Pretty Pimpin          Kurt Vile
# 0                                I Need My Girl       The National
# 0                                       Strange        Galaxie 500
# 0                                   Todeswalzer             Windir
# 0                               Blinding Lights         The Weeknd
# ..                                          ...                ...
# 1                                     Apologize        OneRepublic
# 0              Goddamn Lonely Love - Remastered  Drive-By Truckers
# 0                            Graveless yet Dead        Convocation
# 0   Gimme! Gimme! Gimme! (A Man After Midnight)               ABBA
# 0                         Snakes For The Divine       High On Fire
#
#                    song_id popularity
# 0   3l9eg9RtisizG12a1D6nZl          0
# 0   50M7nY1oQuNHecs0ahWAtI         68
# 0   2TTAPkrGQQOZkaUTUlt21Q         48
# 0   7BvcpEdO7PUDGGSER1S9LA         36
# 0   0VjIjW4GlUZAMYd2vXMi3b         93
# ..                     ...        ...
# 1   6ucR4KfvsBFWCMVFDvyKKl         75
# 0   241LK9hqfXJyWpQ7oClQSN         48
# 0   6hF9etLMoADWLsoui5ejGW         19
# 0   3vkQ5DAB1qQMYO4Mr9zJN6         84
# 0   4dT9raTvZyaeUnNC3qdTXB         44
#
# [4953 rows x 4 columns]

# %%
df_final.isna().sum()
# Out:
# song_name     0
# name          0
# song_id       0
# popularity    0
# dtype: int64

# %%
list_id = df_final['song_id'][0:5]
list_id
# Out:
# 0    3l9eg9RtisizG12a1D6nZl
# 0    50M7nY1oQuNHecs0ahWAtI
# 0    2TTAPkrGQQOZkaUTUlt21Q
# 0    7BvcpEdO7PUDGGSER1S9LA
# 0    0VjIjW4GlUZAMYd2vXMi3b
# Name: song_id, dtype: object

# %%
# sp.audio_features(list_id)

# %%
chunks = [(i, i+100) for i in range(0, len(df_final), 100)]
# chunks

# %%
chunks[0:2]
# Out:
# [(0, 100), (100, 200)]

# %%
chunks = [(i, i+100) for i in range(0, len(df_final), 100)]

audio_features_list = []
for chunk in chunks:
    id_list100 = df_final['song_id'][chunk[0]:chunk[1]]
    audio_features_list = audio_features_list + sp.audio_features(id_list100)
    sleep(randint(1,3000)/1000)
len(audio_features_list)
# Out:
# 4953

# %%
# audio_features_list

# %%
audio_features_df = json_normalize(audio_features_list)

# %%
audio_features_df.drop_duplicates(inplace=True)
audio_features_df.head(5)
# Out:
#    danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0         0.566   0.664    8    -9.081     1       0.0281      0.092800
# 1         0.520   0.436    0   -11.508     0       0.0355      0.865000
# 2         0.312   0.844    7    -7.085     1       0.0511      0.079800
# 3         0.236   0.870    2    -4.747     0       0.0579      0.000011
# 4         0.514   0.730    1    -5.934     1       0.0598      0.001460
#
#    instrumentalness  liveness  valence    tempo            type  \
# 0          0.305000    0.0903    0.764   91.117  audio_features
# 1          0.065100    0.1230    0.114  126.053  audio_features
# 2          0.023100    0.0793    0.626   97.039  audio_features
# 3          0.930000    0.3050    0.186  167.845  audio_features
# 4          0.000095    0.0897    0.334  171.005  audio_features
#
#                        id                                   uri  \
# 0  3l9eg9RtisizG12a1D6nZl  spotify:track:3l9eg9RtisizG12a1D6nZl
# 1  50M7nY1oQuNHecs0ahWAtI  spotify:track:50M7nY1oQuNHecs0ahWAtI
# 2  2TTAPkrGQQOZkaUTUlt21Q  spotify:track:2TTAPkrGQQOZkaUTUlt21Q
# 3  7BvcpEdO7PUDGGSER1S9LA  spotify:track:7BvcpEdO7PUDGGSER1S9LA
# 4  0VjIjW4GlUZAMYd2vXMi3b  spotify:track:0VjIjW4GlUZAMYd2vXMi3b
#
#                                           track_href  \
# 0  https://api.spotify.com/v1/tracks/3l9eg9Rtisiz...
# 1  https://api.spotify.com/v1/tracks/50M7nY1oQuNH...
# 2  https://api.spotify.com/v1/tracks/2TTAPkrGQQOZ...
# 3  https://api.spotify.com/v1/tracks/7BvcpEdO7PUD...
# 4  https://api.spotify.com/v1/tracks/0VjIjW4GlUZA...
#
#                                         analysis_url  duration_ms  \
# 0  https://api.spotify.com/v1/audio-analysis/3l9e...       298760
# 1  https://api.spotify.com/v1/audio-analysis/50M7...       245240
# 2  https://api.spotify.com/v1/audio-analysis/2TTA...       199467
# 3  https://api.spotify.com/v1/audio-analysis/7Bvc...       295131
# 4  https://api.spotify.com/v1/audio-analysis/0VjI...       200040
#
#    time_signature
# 0               4
# 1               4
# 2               4
# 3               4
# 4               4

# %%
pd.set_option('display.max_columns', None)
df_audio_features = pd.merge(left=df_final,
                        right=audio_features_df,
                        how='inner',
                        left_on='song_id',
                        right_on='id')
df_audio_features
# Out:
#                                         song_name               name  \
# 0                                   Pretty Pimpin          Kurt Vile
# 1                                  I Need My Girl       The National
# 2                                         Strange        Galaxie 500
# 3                                     Todeswalzer             Windir
# 4                                 Blinding Lights         The Weeknd
# ...                                           ...                ...
# 4948                                    Apologize        OneRepublic
# 4949             Goddamn Lonely Love - Remastered  Drive-By Truckers
# 4950                           Graveless yet Dead        Convocation
# 4951  Gimme! Gimme! Gimme! (A Man After Midnight)               ABBA
# 4952                        Snakes For The Divine       High On Fire
#
#                      song_id popularity  danceability  energy  key  loudness  \
# 0     3l9eg9RtisizG12a1D6nZl          0         0.566   0.664    8    -9.081
# 1     50M7nY1oQuNHecs0ahWAtI         68         0.520   0.436    0   -11.508
# 2     2TTAPkrGQQOZkaUTUlt21Q         48         0.312   0.844    7    -7.085
# 3     7BvcpEdO7PUDGGSER1S9LA         36         0.236   0.870    2    -4.747
# 4     0VjIjW4GlUZAMYd2vXMi3b         93         0.514   0.730    1    -5.934
# ...                      ...        ...           ...     ...  ...       ...
# 4948  6ucR4KfvsBFWCMVFDvyKKl         75         0.653   0.604    8    -6.017
# 4949  241LK9hqfXJyWpQ7oClQSN         48         0.427   0.541    7    -7.042
# 4950  6hF9etLMoADWLsoui5ejGW         19         0.262   0.689    2    -8.342
# 4951  3vkQ5DAB1qQMYO4Mr9zJN6         84         0.749   0.491   10    -9.655
# 4952  4dT9raTvZyaeUnNC3qdTXB         44         0.228   0.966    1    -5.959
#
#       mode  speechiness  acousticness  instrumentalness  liveness  valence  \
# 0        1       0.0281      0.092800          0.305000    0.0903    0.764
# 1        0       0.0355      0.865000          0.065100    0.1230    0.114
# 2        1       0.0511      0.079800          0.023100    0.0793    0.626
# 3        0       0.0579      0.000011          0.930000    0.3050    0.186
# 4        1       0.0598      0.001460          0.000095    0.0897    0.334
# ...    ...          ...           ...               ...       ...      ...
# 4948     1       0.0278      0.029200          0.000000    0.0970    0.101
# 4949     1       0.0294      0.107000          0.004810    0.2230    0.153
# 4950     1       0.0705      0.036600          0.008330    0.1170    0.178
# 4951     1       0.0403      0.020000          0.008990    0.1590    0.536
# 4952     1       0.0565      0.000027          0.664000    0.3370    0.336
#
#         tempo            type                      id  \
# 0      91.117  audio_features  3l9eg9RtisizG12a1D6nZl
# 1     126.053  audio_features  50M7nY1oQuNHecs0ahWAtI
# 2      97.039  audio_features  2TTAPkrGQQOZkaUTUlt21Q
# 3     167.845  audio_features  7BvcpEdO7PUDGGSER1S9LA
# 4     171.005  audio_features  0VjIjW4GlUZAMYd2vXMi3b
# ...       ...             ...                     ...
# 4948  118.016  audio_features  6ucR4KfvsBFWCMVFDvyKKl
# 4949  119.094  audio_features  241LK9hqfXJyWpQ7oClQSN
# 4950  130.110  audio_features  6hF9etLMoADWLsoui5ejGW
# 4951  119.528  audio_features  3vkQ5DAB1qQMYO4Mr9zJN6
# 4952  139.800  audio_features  4dT9raTvZyaeUnNC3qdTXB
#
#                                        uri  \
# 0     spotify:track:3l9eg9RtisizG12a1D6nZl
# 1     spotify:track:50M7nY1oQuNHecs0ahWAtI
# 2     spotify:track:2TTAPkrGQQOZkaUTUlt21Q
# 3     spotify:track:7BvcpEdO7PUDGGSER1S9LA
# 4     spotify:track:0VjIjW4GlUZAMYd2vXMi3b
# ...                                    ...
# 4948  spotify:track:6ucR4KfvsBFWCMVFDvyKKl
# 4949  spotify:track:241LK9hqfXJyWpQ7oClQSN
# 4950  spotify:track:6hF9etLMoADWLsoui5ejGW
# 4951  spotify:track:3vkQ5DAB1qQMYO4Mr9zJN6
# 4952  spotify:track:4dT9raTvZyaeUnNC3qdTXB
#
#                                              track_href  \
# 0     https://api.spotify.com/v1/tracks/3l9eg9Rtisiz...
# 1     https://api.spotify.com/v1/tracks/50M7nY1oQuNH...
# 2     https://api.spotify.com/v1/tracks/2TTAPkrGQQOZ...
# 3     https://api.spotify.com/v1/tracks/7BvcpEdO7PUD...
# 4     https://api.spotify.com/v1/tracks/0VjIjW4GlUZA...
# ...                                                 ...
# 4948  https://api.spotify.com/v1/tracks/6ucR4KfvsBFW...
# 4949  https://api.spotify.com/v1/tracks/241LK9hqfXJy...
# 4950  https://api.spotify.com/v1/tracks/6hF9etLMoADW...
# 4951  https://api.spotify.com/v1/tracks/3vkQ5DAB1qQM...
# 4952  https://api.spotify.com/v1/tracks/4dT9raTvZyae...
#
#                                            analysis_url  duration_ms  \
# 0     https://api.spotify.com/v1/audio-analysis/3l9e...       298760
# 1     https://api.spotify.com/v1/audio-analysis/50M7...       245240
# 2     https://api.spotify.com/v1/audio-analysis/2TTA...       199467
# 3     https://api.spotify.com/v1/audio-analysis/7Bvc...       295131
# 4     https://api.spotify.com/v1/audio-analysis/0VjI...       200040
# ...                                                 ...          ...
# 4948  https://api.spotify.com/v1/audio-analysis/6ucR...       184400
# 4949  https://api.spotify.com/v1/audio-analysis/241L...       301720
# 4950  https://api.spotify.com/v1/audio-analysis/6hF9...       572149
# 4951  https://api.spotify.com/v1/audio-analysis/3vkQ...       292613
# 4952  https://api.spotify.com/v1/audio-analysis/4dT9...       503760
#
#       time_signature
# 0                  4
# 1                  4
# 2                  4
# 3                  4
# 4                  4
# ...              ...
# 4948               4
# 4949               4
# 4950               4
# 4951               4
# 4952               4
#
# [4953 rows x 22 columns]

# %%
df_audio_features['popularity'].dtype
# Out:
# dtype('O')

# %%
df_audio_features['popularity'] = df_audio_features['popularity'].astype(int)
df_audio_features['popularity'].dtype
# Out:
# dtype('int32')

# %% [markdown]
# ## Clustering

# %%
import numpy as np
import matplotlib.pyplot as plt

from sklearn import cluster, datasets
from sklearn.preprocessing import StandardScaler
from matplotlib.lines import Line2D
from sklearn.cluster import KMeans

# %%
X_num=df_audio_features.select_dtypes(include=['number'])
X_num
# Out:
#       popularity  danceability  energy  key  loudness  mode  speechiness  \
# 0              0         0.566   0.664    8    -9.081     1       0.0281
# 1             68         0.520   0.436    0   -11.508     0       0.0355
# 2             48         0.312   0.844    7    -7.085     1       0.0511
# 3             36         0.236   0.870    2    -4.747     0       0.0579
# 4             93         0.514   0.730    1    -5.934     1       0.0598
# ...          ...           ...     ...  ...       ...   ...          ...
# 4948          75         0.653   0.604    8    -6.017     1       0.0278
# 4949          48         0.427   0.541    7    -7.042     1       0.0294
# 4950          19         0.262   0.689    2    -8.342     1       0.0705
# 4951          84         0.749   0.491   10    -9.655     1       0.0403
# 4952          44         0.228   0.966    1    -5.959     1       0.0565
#
#       acousticness  instrumentalness  liveness  valence    tempo  duration_ms  \
# 0         0.092800          0.305000    0.0903    0.764   91.117       298760
# 1         0.865000          0.065100    0.1230    0.114  126.053       245240
# 2         0.079800          0.023100    0.0793    0.626   97.039       199467
# 3         0.000011          0.930000    0.3050    0.186  167.845       295131
# 4         0.001460          0.000095    0.0897    0.334  171.005       200040
# ...            ...               ...       ...      ...      ...          ...
# 4948      0.029200          0.000000    0.0970    0.101  118.016       184400
# 4949      0.107000          0.004810    0.2230    0.153  119.094       301720
# 4950      0.036600          0.008330    0.1170    0.178  130.110       572149
# 4951      0.020000          0.008990    0.1590    0.536  119.528       292613
# 4952      0.000027          0.664000    0.3370    0.336  139.800       503760
#
#       time_signature
# 0                  4
# 1                  4
# 2                  4
# 3                  4
# 4                  4
# ...              ...
# 4948               4
# 4949               4
# 4950               4
# 4951               4
# 4952               4
#
# [4953 rows x 14 columns]

# %%
X_prep = StandardScaler().fit_transform(X_num)

# Now, all features will have the same weight.
pd.DataFrame(X_prep,columns=X_num.columns).head()
# Out:
#    popularity  danceability    energy       key  loudness      mode  \
# 0   -1.171821      0.733987 -0.398752  0.751737 -0.404737  0.729068
# 1    1.405339      0.491138 -1.398067 -1.513938 -1.074227 -1.371615
# 2    0.647351     -0.606961  0.390181  0.468528  0.145862  0.729068
# 3    0.192558     -1.008189  0.504138 -0.947520  0.790802 -1.371615
# 4    2.352824      0.459463 -0.109477 -1.230729  0.463367  0.729068
#
#    speechiness  acousticness  instrumentalness  liveness   valence     tempo  \
# 0    -0.796695     -0.208804          0.213107 -0.762843  1.344064 -1.166039
# 1    -0.687783      2.811565         -0.501272 -0.565416 -1.114800  0.029047
# 2    -0.458186     -0.259652         -0.626340 -0.829256  0.822028 -0.963460
# 3    -0.358105     -0.571739          2.074245  0.533415 -0.842434  1.458663
# 4    -0.330141     -0.566070         -0.694844 -0.766465 -0.282569  1.566759
#
#    duration_ms  time_signature
# 0     0.240063        0.233789
# 1    -0.159999        0.233789
# 2    -0.502152        0.233789
# 3     0.212937        0.233789
# 4    -0.497869        0.233789

# %%
kmeans = KMeans(n_clusters=6, random_state=1234)
kmeans.fit(X_prep)
# Out:
# C:\ANACONDA3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# KMeans(n_clusters=6, random_state=1234)

# %%
# Predicting / assigning the clusters:
clusters = kmeans.predict(X_prep)

# Check the size of the clusters
pd.Series(clusters).value_counts().sort_index()
# Out:
# 0    1291
# 1    1445
# 2     261
# 3     649
# 4     287
# 5    1020
# Name: count, dtype: int64

# %%
type(clusters)
# Out:
# numpy.ndarray

# %%
plt.figure(figsize=(5, 5))
plt.scatter(X_prep[:, 0], X_prep[:, 1], c=clusters,alpha=0.5)
plt.show()

# %%
kmeans.inertia_
# Out:
# 45524.502703643026

# %%
# %%time
kmeans = KMeans(n_clusters=6,
                init="random",
                n_init= 1,  # try with 1, 4, 8, 20, 30, 100...
                max_iter=10,
                tol=0,
                random_state=1234)
kmeans.fit(X_prep)
print(kmeans.inertia_)
# Out:
# 46305.48058159361
# CPU times: total: 78.1 ms
# Wall time: 88.9 ms

# %% [markdown]
# # Choosing K

# %%
K = range(2, 20)
inertia = []

for k in K:
    kmeans = KMeans(n_clusters=k,
                    random_state=1234)
    kmeans.fit(X_prep)
    inertia.append(kmeans.inertia_)

import matplotlib.pyplot as plt
# %matplotlib inline

plt.figure(figsize=(16,8))
plt.plot(K, inertia, 'bx-')
plt.xlabel('k')
plt.ylabel('inertia')
plt.xticks(np.arange(min(K), max(K)+1, 1.0))
plt.title('Elbow Method showing the optimal k')
# Out:
# C:\ANACONDA3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\ANACONDA3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\ANACONDA3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\ANACONDA3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\ANACONDA3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\ANACONDA3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\ANACONDA3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\ANACONDA3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\ANACONDA3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\ANACONDA3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\ANACONDA3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\ANACONDA3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\ANACONDA3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\ANACONDA3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\ANACONDA3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\ANACONDA3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\ANACONDA3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\ANACONDA3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# Text(0.5, 1.0, 'Elbow Method showing the optimal k')

# %%
from sklearn.metrics import silhouette_score
K = range(2, 20)
silhouette = []

for k in K:
    kmeans = KMeans(n_clusters=k,
                    random_state=1234)
    kmeans.fit(X_prep)
    silhouette.append(silhouette_score(X_prep, kmeans.predict(X_prep)))


plt.figure(figsize=(16,8))
plt.plot(K, silhouette, 'bx-')
plt.xlabel('k')
plt.ylabel('silhouette score')
plt.xticks(np.arange(min(K), max(K)+1, 1.0))
plt.title('Slhouette score showing the optimal k')
# Out:
# C:\ANACONDA3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\ANACONDA3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\ANACONDA3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\ANACONDA3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\ANACONDA3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\ANACONDA3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\ANACONDA3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\ANACONDA3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\ANACONDA3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\ANACONDA3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\ANACONDA3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\ANACONDA3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\ANACONDA3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\ANACONDA3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\ANACONDA3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\ANACONDA3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\ANACONDA3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\ANACONDA3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# Text(0.5, 1.0, 'Slhouette score showing the optimal k')

# %%
# join clusters as a cloumn 
# concat with original df

# %%
df_clusters=pd.DataFrame(clusters,columns=['clustr_nu'])
df_clusters.head()
# Out:
#    clustr_nu
# 0          1
# 1          3
# 2          1
# 3          5
# 4          1

# %%
df_audio_features_final= pd.concat([df_audio_features,df_clusters], axis=1)
df_audio_features_final
# Out:
#                                         song_name               name  \
# 0                                   Pretty Pimpin          Kurt Vile
# 1                                  I Need My Girl       The National
# 2                                         Strange        Galaxie 500
# 3                                     Todeswalzer             Windir
# 4                                 Blinding Lights         The Weeknd
# ...                                           ...                ...
# 4948                                    Apologize        OneRepublic
# 4949             Goddamn Lonely Love - Remastered  Drive-By Truckers
# 4950                           Graveless yet Dead        Convocation
# 4951  Gimme! Gimme! Gimme! (A Man After Midnight)               ABBA
# 4952                        Snakes For The Divine       High On Fire
#
#                      song_id  popularity  danceability  energy  key  loudness  \
# 0     3l9eg9RtisizG12a1D6nZl           0         0.566   0.664    8    -9.081
# 1     50M7nY1oQuNHecs0ahWAtI          68         0.520   0.436    0   -11.508
# 2     2TTAPkrGQQOZkaUTUlt21Q          48         0.312   0.844    7    -7.085
# 3     7BvcpEdO7PUDGGSER1S9LA          36         0.236   0.870    2    -4.747
# 4     0VjIjW4GlUZAMYd2vXMi3b          93         0.514   0.730    1    -5.934
# ...                      ...         ...           ...     ...  ...       ...
# 4948  6ucR4KfvsBFWCMVFDvyKKl          75         0.653   0.604    8    -6.017
# 4949  241LK9hqfXJyWpQ7oClQSN          48         0.427   0.541    7    -7.042
# 4950  6hF9etLMoADWLsoui5ejGW          19         0.262   0.689    2    -8.342
# 4951  3vkQ5DAB1qQMYO4Mr9zJN6          84         0.749   0.491   10    -9.655
# 4952  4dT9raTvZyaeUnNC3qdTXB          44         0.228   0.966    1    -5.959
#
#       mode  speechiness  acousticness  instrumentalness  liveness  valence  \
# 0        1       0.0281      0.092800          0.305000    0.0903    0.764
# 1        0       0.0355      0.865000          0.065100    0.1230    0.114
# 2        1       0.0511      0.079800          0.023100    0.0793    0.626
# 3        0       0.0579      0.000011          0.930000    0.3050    0.186
# 4        1       0.0598      0.001460          0.000095    0.0897    0.334
# ...    ...          ...           ...               ...       ...      ...
# 4948     1       0.0278      0.029200          0.000000    0.0970    0.101
# 4949     1       0.0294      0.107000          0.004810    0.2230    0.153
# 4950     1       0.0705      0.036600          0.008330    0.1170    0.178
# 4951     1       0.0403      0.020000          0.008990    0.1590    0.536
# 4952     1       0.0565      0.000027          0.664000    0.3370    0.336
#
#         tempo            type                      id  \
# 0      91.117  audio_features  3l9eg9RtisizG12a1D6nZl
# 1     126.053  audio_features  50M7nY1oQuNHecs0ahWAtI
# 2      97.039  audio_features  2TTAPkrGQQOZkaUTUlt21Q
# 3     167.845  audio_features  7BvcpEdO7PUDGGSER1S9LA
# 4     171.005  audio_features  0VjIjW4GlUZAMYd2vXMi3b
# ...       ...             ...                     ...
# 4948  118.016  audio_features  6ucR4KfvsBFWCMVFDvyKKl
# 4949  119.094  audio_features  241LK9hqfXJyWpQ7oClQSN
# 4950  130.110  audio_features  6hF9etLMoADWLsoui5ejGW
# 4951  119.528  audio_features  3vkQ5DAB1qQMYO4Mr9zJN6
# 4952  139.800  audio_features  4dT9raTvZyaeUnNC3qdTXB
#
#                                        uri  \
# 0     spotify:track:3l9eg9RtisizG12a1D6nZl
# 1     spotify:track:50M7nY1oQuNHecs0ahWAtI
# 2     spotify:track:2TTAPkrGQQOZkaUTUlt21Q
# 3     spotify:track:7BvcpEdO7PUDGGSER1S9LA
# 4     spotify:track:0VjIjW4GlUZAMYd2vXMi3b
# ...                                    ...
# 4948  spotify:track:6ucR4KfvsBFWCMVFDvyKKl
# 4949  spotify:track:241LK9hqfXJyWpQ7oClQSN
# 4950  spotify:track:6hF9etLMoADWLsoui5ejGW
# 4951  spotify:track:3vkQ5DAB1qQMYO4Mr9zJN6
# 4952  spotify:track:4dT9raTvZyaeUnNC3qdTXB
#
#                                              track_href  \
# 0     https://api.spotify.com/v1/tracks/3l9eg9Rtisiz...
# 1     https://api.spotify.com/v1/tracks/50M7nY1oQuNH...
# 2     https://api.spotify.com/v1/tracks/2TTAPkrGQQOZ...
# 3     https://api.spotify.com/v1/tracks/7BvcpEdO7PUD...
# 4     https://api.spotify.com/v1/tracks/0VjIjW4GlUZA...
# ...                                                 ...
# 4948  https://api.spotify.com/v1/tracks/6ucR4KfvsBFW...
# 4949  https://api.spotify.com/v1/tracks/241LK9hqfXJy...
# 4950  https://api.spotify.com/v1/tracks/6hF9etLMoADW...
# 4951  https://api.spotify.com/v1/tracks/3vkQ5DAB1qQM...
# 4952  https://api.spotify.com/v1/tracks/4dT9raTvZyae...
#
#                                            analysis_url  duration_ms  \
# 0     https://api.spotify.com/v1/audio-analysis/3l9e...       298760
# 1     https://api.spotify.com/v1/audio-analysis/50M7...       245240
# 2     https://api.spotify.com/v1/audio-analysis/2TTA...       199467
# 3     https://api.spotify.com/v1/audio-analysis/7Bvc...       295131
# 4     https://api.spotify.com/v1/audio-analysis/0VjI...       200040
# ...                                                 ...          ...
# 4948  https://api.spotify.com/v1/audio-analysis/6ucR...       184400
# 4949  https://api.spotify.com/v1/audio-analysis/241L...       301720
# 4950  https://api.spotify.com/v1/audio-analysis/6hF9...       572149
# 4951  https://api.spotify.com/v1/audio-analysis/3vkQ...       292613
# 4952  https://api.spotify.com/v1/audio-analysis/4dT9...       503760
#
#       time_signature  clustr_nu
# 0                  4          1
# 1                  4          3
# 2                  4          1
# 3                  4          5
# 4                  4          1
# ...              ...        ...
# 4948               4          1
# 4949               4          1
# 4950               4          5
# 4951               4          1
# 4952               4          5
#
# [4953 rows x 23 columns]

# %%
equal_values = df_audio_features_final['song_id'] == df_audio_features_final['id']
equal_values.value_counts()
# Out:
# True    4953
# Name: count, dtype: int64

# %%
# drop recurring columns song_id and id
df_audio_features_final =df_audio_features_final.drop('id', axis=1)
df_audio_features_final =df_audio_features_final.drop('type', axis=1)
df_audio_features_final
# Out:
#                                         song_name               name  \
# 0                                   Pretty Pimpin          Kurt Vile
# 1                                  I Need My Girl       The National
# 2                                         Strange        Galaxie 500
# 3                                     Todeswalzer             Windir
# 4                                 Blinding Lights         The Weeknd
# ...                                           ...                ...
# 4948                                    Apologize        OneRepublic
# 4949             Goddamn Lonely Love - Remastered  Drive-By Truckers
# 4950                           Graveless yet Dead        Convocation
# 4951  Gimme! Gimme! Gimme! (A Man After Midnight)               ABBA
# 4952                        Snakes For The Divine       High On Fire
#
#                      song_id  popularity  danceability  energy  key  loudness  \
# 0     3l9eg9RtisizG12a1D6nZl           0         0.566   0.664    8    -9.081
# 1     50M7nY1oQuNHecs0ahWAtI          68         0.520   0.436    0   -11.508
# 2     2TTAPkrGQQOZkaUTUlt21Q          48         0.312   0.844    7    -7.085
# 3     7BvcpEdO7PUDGGSER1S9LA          36         0.236   0.870    2    -4.747
# 4     0VjIjW4GlUZAMYd2vXMi3b          93         0.514   0.730    1    -5.934
# ...                      ...         ...           ...     ...  ...       ...
# 4948  6ucR4KfvsBFWCMVFDvyKKl          75         0.653   0.604    8    -6.017
# 4949  241LK9hqfXJyWpQ7oClQSN          48         0.427   0.541    7    -7.042
# 4950  6hF9etLMoADWLsoui5ejGW          19         0.262   0.689    2    -8.342
# 4951  3vkQ5DAB1qQMYO4Mr9zJN6          84         0.749   0.491   10    -9.655
# 4952  4dT9raTvZyaeUnNC3qdTXB          44         0.228   0.966    1    -5.959
#
#       mode  speechiness  acousticness  instrumentalness  liveness  valence  \
# 0        1       0.0281      0.092800          0.305000    0.0903    0.764
# 1        0       0.0355      0.865000          0.065100    0.1230    0.114
# 2        1       0.0511      0.079800          0.023100    0.0793    0.626
# 3        0       0.0579      0.000011          0.930000    0.3050    0.186
# 4        1       0.0598      0.001460          0.000095    0.0897    0.334
# ...    ...          ...           ...               ...       ...      ...
# 4948     1       0.0278      0.029200          0.000000    0.0970    0.101
# 4949     1       0.0294      0.107000          0.004810    0.2230    0.153
# 4950     1       0.0705      0.036600          0.008330    0.1170    0.178
# 4951     1       0.0403      0.020000          0.008990    0.1590    0.536
# 4952     1       0.0565      0.000027          0.664000    0.3370    0.336
#
#         tempo                                   uri  \
# 0      91.117  spotify:track:3l9eg9RtisizG12a1D6nZl
# 1     126.053  spotify:track:50M7nY1oQuNHecs0ahWAtI
# 2      97.039  spotify:track:2TTAPkrGQQOZkaUTUlt21Q
# 3     167.845  spotify:track:7BvcpEdO7PUDGGSER1S9LA
# 4     171.005  spotify:track:0VjIjW4GlUZAMYd2vXMi3b
# ...       ...                                   ...
# 4948  118.016  spotify:track:6ucR4KfvsBFWCMVFDvyKKl
# 4949  119.094  spotify:track:241LK9hqfXJyWpQ7oClQSN
# 4950  130.110  spotify:track:6hF9etLMoADWLsoui5ejGW
# 4951  119.528  spotify:track:3vkQ5DAB1qQMYO4Mr9zJN6
# 4952  139.800  spotify:track:4dT9raTvZyaeUnNC3qdTXB
#
#                                              track_href  \
# 0     https://api.spotify.com/v1/tracks/3l9eg9Rtisiz...
# 1     https://api.spotify.com/v1/tracks/50M7nY1oQuNH...
# 2     https://api.spotify.com/v1/tracks/2TTAPkrGQQOZ...
# 3     https://api.spotify.com/v1/tracks/7BvcpEdO7PUD...
# 4     https://api.spotify.com/v1/tracks/0VjIjW4GlUZA...
# ...                                                 ...
# 4948  https://api.spotify.com/v1/tracks/6ucR4KfvsBFW...
# 4949  https://api.spotify.com/v1/tracks/241LK9hqfXJy...
# 4950  https://api.spotify.com/v1/tracks/6hF9etLMoADW...
# 4951  https://api.spotify.com/v1/tracks/3vkQ5DAB1qQM...
# 4952  https://api.spotify.com/v1/tracks/4dT9raTvZyae...
#
#                                            analysis_url  duration_ms  \
# 0     https://api.spotify.com/v1/audio-analysis/3l9e...       298760
# 1     https://api.spotify.com/v1/audio-analysis/50M7...       245240
# 2     https://api.spotify.com/v1/audio-analysis/2TTA...       199467
# 3     https://api.spotify.com/v1/audio-analysis/7Bvc...       295131
# 4     https://api.spotify.com/v1/audio-analysis/0VjI...       200040
# ...                                                 ...          ...
# 4948  https://api.spotify.com/v1/audio-analysis/6ucR...       184400
# 4949  https://api.spotify.com/v1/audio-analysis/241L...       301720
# 4950  https://api.spotify.com/v1/audio-analysis/6hF9...       572149
# 4951  https://api.spotify.com/v1/audio-analysis/3vkQ...       292613
# 4952  https://api.spotify.com/v1/audio-analysis/4dT9...       503760
#
#       time_signature  clustr_nu
# 0                  4          1
# 1                  4          3
# 2                  4          1
# 3                  4          5
# 4                  4          1
# ...              ...        ...
# 4948               4          1
# 4949               4          1
# 4950               4          5
# 4951               4          1
# 4952               4          5
#
# [4953 rows x 21 columns]
